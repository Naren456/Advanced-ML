# %%
import pandas as pd

# %%
df =  pd.read_csv("StudentPerformanceFactors.csv")

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.Parental_Involvement.value_counts()
# Out:
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
df['Parental_Involvement'] = encoder.fit_transform(df[['Parental_Involvement']])

# %%
df.Access_to_Resources.value_counts()
# Out:
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64

# %%
encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
df['Access_to_Resources'] = encoder.fit_transform(df[['Access_to_Resources']])

# %%
df.Extracurricular_Activities.value_counts()
# Out:
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64

# %%
df["Extracurricular_Activities"] = df["Extracurricular_Activities"].map({"Yes": 1, "No": 0})

# %%
df.Motivation_Level.value_counts()
# Out:
# Motivation_Level
# Medium    3351
# Low       1937
# High      1319
# Name: count, dtype: int64

# %%
encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
df['Motivation_Level'] = encoder.fit_transform(df[['Motivation_Level']])

# %%
df.Internet_Access.value_counts()
# Out:
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64

# %%
df["Internet_Access"] = df["Internet_Access"].map({"Yes": 1, "No": 0})

# %%
df.Family_Income.value_counts()
# Out:
# Family_Income
# Low       2672
# Medium    2666
# High      1269
# Name: count, dtype: int64

# %%
encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
df['Family_Income'] = encoder.fit_transform(df[['Family_Income']])

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                   0.0                  2.0
# 1             19          64                   0.0                  1.0
# 2             24          98                   1.0                  1.0
# 3             29          89                   0.0                  1.0
# 4             19          92                   1.0                  1.0
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                           0            7               73               0.0
# 1                           0            8               59               0.0
# 2                           1            7               91               1.0
# 3                           1            8               98               1.0
# 4                           1            6               65               1.0
#
# ...

# %%
df.Teacher_Quality.value_counts()
# Out:
# Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   float64
#  3   Access_to_Resources         6607 non-null   float64
#  4   Extracurricular_Activities  6607 non-null   int64
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   float64
#  8   Internet_Access             6607 non-null   int64
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   float64
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.Teacher_Quality.isnull().value_counts()
# Out:
# Teacher_Quality
# False    6529
# True       78
# Name: count, dtype: int64

# %%
encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
df['Teacher_Quality'] = encoder.fit_transform(df[['Teacher_Quality']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
# ----> 2 df['Teacher_Quality'] = encoder.fit_transform(df[['Teacher_Quality']])
#
# File /media/narendra/52cb030f-a277-43de-99fb-50a567eb224f/Scaler/Semester 3/Term 2/Advanced ML/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
